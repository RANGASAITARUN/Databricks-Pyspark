# %%
# Application (client) ID
# :
# 628c97f2-d75d-4280-ad5d-41f079f7705d

# Directory (tenant) ID
# :
# fd5f53a9-a4c5-4568-907e-9c903acded40


# databricks-secret-value:ylt8Q~rLsLGkLyBvb5JR30IRY8OBNO6zrmgYubvy

# %%
# step-1:App registration in active directory  create new app and give required details.From there you will get client_id,tenant_id.
#        In active directory there is option called certificates go there click on new client secret copy the value(databricks-secret-value)
# step-2:go to adlgen2 under access control click on role-assignment and provide require details(storage blob data contributor,members(app registed in active directory))
# # step-3:mount the storage account in data bricks

# %%
storage_account_name = "sai1234"
client_id            = "628c97f2-d75d-4280-ad5d-41f079f7705d"
tenant_id            = "fd5f53a9-a4c5-4568-907e-9c903acded40"
client_secret        = "ylt8Q~rLsLGkLyBvb5JR30IRY8OBNO6zrmgYubvy"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
configs = {"fs.azure.account.auth.type": "OAuth",
           "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
           "fs.azure.account.oauth2.client.id": f"{client_id}",
           "fs.azure.account.oauth2.client.secret": f"{client_secret}",
           "fs.azure.account.oauth2.client.endpoint": f"https://login.microsoftonline.com/{tenant_id}/oauth2/token"}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
container_name = "raw"
dbutils.fs.mount(
  source = f"abfss://{container_name}@{storage_account_name}.dfs.core.windows.net/",
  mount_point = f"/mnt/{storage_account_name}/{container_name}",
  extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: True</div>

# %%
dbutils.fs.ls("/mnt/sai1234/raw")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: []</div>
